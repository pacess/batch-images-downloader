# %% [markdown]
# # Batch Image Downloader for boolwowgirls.com All Graphis

# %%
from user_agent import generate_user_agent
from bs4 import BeautifulSoup
from random import randint
from pathlib import Path
import urllib.parse
import requests
import shutil
import os

# %%
##  https://boolwowgirls.com/photos-category/graphis/
_url = "https://boolwowgirls.com/photos-category/graphis/"

_outputPath = "../Dataset/Photos/Adult/boolwowgirls.com"

# %%
def downloadAlbum(url):

    userAgent = generate_user_agent()
    headers = {"user-agent":userAgent, "referer":_url}
    httpRequest = requests.get(url=url, headers=headers)
    soup = BeautifulSoup(httpRequest.text, "html.parser")
    print(httpRequest.url)

    objectList = soup.findAll("img", attrs={"data-original-width":True, "data-lazy-src":True})
    if (objectList is None):
        return

    for imageObject in objectList:

        imageURL = imageObject.get("data-lazy-src")
        if (imageURL is None):
            print("### Image URL for '"+filename+"'not found...")
            print(soup)
            finish = True
            return

        ##  Download image
        imageURL = imageURL.rstrip()
        imageFilename = imageURL.split("/")[-1]
        imageFilename = imageFilename.split("?")[0]

        #print("Downloading "+imageURL+"...")
        imageURL = imageURL+"?v="+str(randint(1, 100))
        httpRequest = requests.get(imageURL, headers=headers, stream=True)
        if (httpRequest.status_code != 200):
            print("### Unable to download image...\n")
            continue

        ##  Set true to prevent image size zero
        httpRequest.raw.decode_content = True

        ##  Save image
        path = Path(url)
        pathName = urllib.parse.unquote(path.name)
        filePath = os.path.join(_outputPath, pathName)
        exist = os.path.exists(filePath)
        if (exist == False):

            ##  Create path
            os.makedirs(filePath)

        filePath = os.path.join(filePath, imageFilename)
        with open(filePath, "wb") as file:

            shutil.copyfileobj(httpRequest.raw, file)

# %%
finish = False
albumURL = _url
for i in range(20):

    page = i+1
    print("Album page #"+str(page)+"...")

    url = albumURL
    if (page > 1):
        url = albumURL+"page/"+str(page)+"/"
    
    userAgent = generate_user_agent()
    headers = {"user-agent":userAgent, "referer":_url}
    httpRequest = requests.get(url=url, headers=headers)
    soup = BeautifulSoup(httpRequest.text, "html.parser")

    headerObject = soup.find("h1", attrs={"class":"widget-title"})
    if (headerObject):
        if ("Oops" in headerObject.text):
            break
    
    albumList = soup.findAll("a", attrs={"title":True})
    if (albumList is None):
        break

    for linkObject in albumList:

        ##  Check if it is Graphis album
        title = linkObject.get("title")
        if "Graphis" not in title:
            continue

        ##  Yes, Graphis album
        url = linkObject.get("href")
        downloadAlbum(url)

    if (finish == True):
        break

print("Finish all!")
# Out:
# Album page #1...
# https://boolwowgirls.com/photos/graphis-mayuki-ito-%E4%BC%8A%E8%97%A4%E8%88%9E%E9%9B%AA-top-jav-actress-2019/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-aoi-%E8%91%B5-uncensored-sexy-girl-in-hot-porn-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-ami-ayuha-%E9%98%BF%E7%94%B1%E8%91%89%E3%81%82%E3%81%BF-xxx-japanese-pornstars-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-momo-sakura-%E6%A1%9C%E7%A9%BA%E3%82%82%E3%82%82-lingerie-nude-babes/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-minami-hatsukawa-%E5%88%9D%E5%B7%9D%E3%81%BF%E3%81%AA%E3%81%BF-tight-nude-tiny-butts-girl/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-maria-aine-%E6%84%9B%E9%9F%B3%E3%81%BE%E3%82%8A%E3%81%82-teen-panty-girl-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-syunka-ayami-%E3%81%82%E3%82%84%E3%81%BF%E6%97%AC%E6%9E%9C-naked-petite-girls/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-airi-suzumura-%E9%88%B4%E6%9D%91%E3%81%82%E3%81%84%E3%82%8A-skinny-nudes-girl-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-shion-utsunomiya-%E5%AE%87%E9%83%BD%E5%AE%AE%E3%81%97%E3%82%92%E3%82%93-japanese-girl-porn-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-nanami-matsumoto-%E6%9D%BE%E6%9C%AC%E8%8F%9C%E5%A5%88%E5%AE%9F-hot-nude-japanese-girl/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-rin-hatsumi-%E5%88%9D%E7%BE%8E%E3%82%8A%E3%82%93-sexy-japanese-teen-girl/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-yua-mikami-%E4%B8%89%E4%B8%8A%E6%82%A0%E4%BA%9C-queen-of-prettiest-jav-pornstar/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-moe-amatsuka-%E5%A4%A9%E4%BD%BF%E3%82%82%E3%81%88-small-tits-girl-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-sarina-kurokawa-%E9%BB%92%E5%B7%9D%E3%82%B5%E3%83%AA%E3%83%8A-hot-black-lingerie/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-kana-momonogi-%E6%A1%83%E4%B9%83%E6%9C%A8%E3%81%8B%E3%81%AA-cutest-jav-pornstars/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-miharu-usa-%E7%BE%BD%E5%92%B2%E3%81%BF%E3%81%AF%E3%82%8B-cutest-japanese-girl-av-idol/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-shoko-takahashi-%E9%AB%98%E6%A9%8B%E3%81%97%E3%82%87%E3%81%86%E5%AD%90-puffy-nipples-girl-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-nanami-matsumoto-%E6%9D%BE%E6%9C%AC%E8%8F%9C%E5%A5%88%E5%AE%9F-sexy-big-tits-girl/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-gals-no-413-hikari-nagisa-%E6%B8%9A%E3%81%B2%E3%81%8B%E3%82%8A-splendid-125p169m/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-gals-no-412-matsuri-kiritani-%E6%A1%90%E8%B0%B7%E3%81%BE%E3%81%A4%E3%82%8A-primula-julian-120p162/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-gals-no-398-airi-suzumura-%E9%88%B4%E6%9D%91-%E3%81%82%E3%81%84%E3%82%8A-certain-existence-170p194m/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-suzu-harumiya-%E6%98%A5%E5%AE%AE%E3%81%99%E3%81%9A-hot-sexy-naughty-girl/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-yua-mikami-%E4%B8%89%E4%B8%8A%E6%82%A0%E4%BA%9C-sexy-beautiful-girl-nude-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-kana-momonogi-%E6%A1%83%E4%B9%83%E6%9C%A8-%E3%81%8B%E3%81%AA-nude-teen-tiny-girl/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-nana-ayano-%E5%BD%A9%E4%B9%83%E3%81%AA%E3%81%AA-cutest-japanese-av-model/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-an-tsujimoto-%E8%BE%BB%E6%9C%AC%E6%9D%8F-sexiest-outdoor-nude-girl/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-shion-utsunomiya-%E5%AE%87%E9%83%BD%E5%AE%AE%E3%81%97%E3%82%92%E3%82%93-big-tits-teen-babes/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-urumi-yurisaki-%E7%99%BE%E5%90%88%E5%92%B2%E3%81%86%E3%82%8B%E3%81%BF-sexy-brunette-girl-naked-photos/
# Finish
#
#
# Album page #2...
# https://boolwowgirls.com/photos/graphis-shoko-takahashi-%E9%AB%98%E6%A9%8B-%E3%81%97%E3%82%87%E3%81%86%E5%AD%90-big-natural-boobs-girl/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-julia-%E3%82%B8%E3%83%A5%E3%83%AA%E3%82%A2-big-natural-tits-girl-pics/
# Finish
#
#
# https://boolwowgirls.com/photos/graphis-hana-aoyama-%E9%9D%92%E5%B1%B1%E3%81%AF%E3%81%AA-outdoor-jav-acstress-show-porn-pics/
