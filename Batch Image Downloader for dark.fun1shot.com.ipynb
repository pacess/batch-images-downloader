# %% [markdown]
# # Batch Image Downloader for dark.fun1shot.com

# %%
from user_agent import generate_user_agent
from bs4 import BeautifulSoup
from random import randint
from pathlib import Path
import requests
import shutil
import os

# %%
##  https://dark.fun1shot.com/article/55714
_url = "https://dark.fun1shot.com/article/55714"

_outputPath = "../Dataset/Photos/Adult/dark.fun1shot.com"

# %%
finish = False
for i in range(100):

    page = i+1
    url = _url
    
    userAgent = generate_user_agent()
    headers = {"user-agent":userAgent, "referer":_url}
    httpRequest = requests.get(url=url, headers=headers)
    soup = BeautifulSoup(httpRequest.text, "html.parser")
    print(httpRequest.url)

    objectList = soup.findAll("img", attrs={"class":"article_img"})
    if (objectList is None):
        break

    for imageObject in objectList:

        imageURL = imageObject.get("src")
        if (imageURL is None):
            print("### Image URL for '"+filename+"'not found...")
            print(soup)
            finish = True
            break

        ##  Download image
        imageURL = imageURL.rstrip()
        imageFilename = imageURL.split("/")[-1]

        print("Downloading "+imageURL+"...")
        imageURL = imageURL+"?v="+str(randint(1, 100))
        httpRequest = requests.get(imageURL, headers=headers, stream=True)
        if (httpRequest.status_code != 200):
            print("### Unable to download image...\n")
            continue

        ##  Set true to prevent image size zero
        httpRequest.raw.decode_content = True

        ##  Save image
        path = Path(_url)
        pathName = path.name
        filePath = os.path.join(_outputPath, pathName)
        exist = os.path.exists(filePath)
        if (exist == False):

            ##  Create path
            os.makedirs(filePath)

        filePath = os.path.join(filePath, imageFilename)
        with open(filePath, "wb") as file:

            shutil.copyfileobj(httpRequest.raw, file)

    ##  Have next page?
    objectList = soup.findAll("a", attrs={"class":"a1"})
    count = len(objectList)
    if (count != 2):
        finish = True

    if (finish == True):
        break

print("\nFinish")
# Out:
# https://dark.fun1shot.com/article/55714
# Downloading https://imgsdark.fun1shot.com/3150bfce40ec6a4999dc5aeaa9ec6fcd.jpg...
# Downloading https://imgsdark.fun1shot.com/25bfa13d65cecc527c0d3ed1205e8773.jpg...
# Downloading https://imgsdark.fun1shot.com/c48b70641e2840d21ae3aa5a720dadbb.jpg...
# Downloading https://imgsdark.fun1shot.com/ca3646ab21e82c5a9e9ba970e2f61111.jpg...
# Downloading https://imgsdark.fun1shot.com/e8cf47a0fb22f40a26f130e45c63b404.jpg...
# Downloading https://imgsdark.fun1shot.com/fd2eb929babce705870865dc0e07ee93.jpg...
# Downloading https://imgsdark.fun1shot.com/6cb3f987548e0168688bec3c0eafd6ee.jpg...
# Downloading https://imgsdark.fun1shot.com/e192897a24cc7cd370d644225693b3ee.jpg...
# Downloading https://imgsdark.fun1shot.com/8fc39d34c1df77707d9aca619266b85c.jpg...
# Downloading https://imgsdark.fun1shot.com/b833c83ec6f9a7df579db6a90d922dcb.jpg...
# Downloading https://imgsdark.fun1shot.com/f1842e53c9d863a77093f30ced8a665e.jpg...
# Downloading https://imgsdark.fun1shot.com/e353c0b6bad84e92c89db44080ca002e.jpg...
